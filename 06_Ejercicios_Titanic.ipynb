# %% [markdown]
# ![logo.png](attachment:logo.png)
#
# #### Módulo 1: Python para la ciencia de datos
# ### Ejercicios. Visualización de datos en pandas

# %% [markdown]
# En este trabajo vamos a realizar una exploración visual de los datos contenidos en el archivo titanic.csv. Para ello, leemos este archivo en un DataFrame y a partir de él creamos las siguientes gráficas. Cada alumno debe pontar la gráfica como crea que se ve más claramente la información requerida. Yo os muestro una posibilidad.
#
# Nuestro DataFrame tiene 12 columnas. Para cada uno de los pasajeros, se guarda la siguiente información:
# * PassengerId: identificador del pasajero
# * Suvived: 0 si no sobrevivió; 1 si sí lo hizo
# * Pclass: 1, 2 o 3: clase en la que viajaba (1 – Primera clase; 2 – Segunda clase; 3 – Tercera clase)
# * Name: Nombre del pasajero
# * Sex: male o female: sexo del pasajero
# * Age: edad
# * SibSp: número de hermanos y cónyuges que viajaban en el barco
# * Parch: número de padres e hijos que viajaban en el barco
# * Ticket: número de ticket
# * Fare: precio del pasaje
# * Cabin: cabina en la que viajaba
# * Embarked: C, Q o S: puerto en el que embarcaron (C – Cherbourg; Q – Queenstown; S – Southampton)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

t=pd.read_csv('titanic.csv')

# %% [markdown]
# #### Apartado 1
# Una de las cosas que más nos interesan sobre el titanic es saber el número de pasajeros que sobrevivieron. Visualizamos en una gráfica de barras el número de supervivientes frente al número de no supervivientes.
# ![ejemplo1.PNG](attachment:ejemplo1.PNG)

# %% [markdown]
# #### Apartado 2
# Además, queremos ver si el número de supervivientes es diferente según el sexo de los pasajeros. Mostrar en una gráfica la misma información del apartado 1, pero diferenciada por sexos.
# ![ejemplo2.PNG](attachment:ejemplo2.PNG)

# %% [markdown]
# #### Apartado 3
# También queremos analizar las edades de los pasajeros del titanic. Mediante un gráfico de cajas (boxplot), vamos a mostrar las edades de los pasajeros, separando los datos de los hombres de los datos de las mujeres.
# ![ejemplo3.PNG](attachment:ejemplo3.PNG)

# %% [markdown]
# #### Apartado 4
# Queremos saber si la tasa de supervivencia dependió de la edad de los viajeros. Además, si este hecho fue diferente para hombres y mujeres. Para ello, mostramos en un gráfico las edades de los supervivientes así como las de los no supervivientes, separando esta información en dos subgráficos: uno para hombres y otro para mujeres.
# ![ejemplo4.PNG](attachment:ejemplo4.PNG)

# %% [markdown]
# #### Apartado 5
# Queremos saber más sobre qué pasajeros viajaban en cada una de las clases. Mostrar en un gráfico de barras el número de pasajeros que viajaban en cada una de las clases.
# ![ejemplo5.PNG](attachment:ejemplo5.PNG)

# %% [markdown]
# #### Apartado 6
# Ahora queremos comprobar si existe una relación entre las edades de los pasajeros y la clase en la que viajaban. Para ello, mostrar en una gráfica el número de viajeros que había en cada clase, según la edad que tenían.
# ![ejemplo6-2.PNG](attachment:ejemplo6-2.PNG)

# %% [markdown]
# #### Apartado 7
# Para intuir qué puertos están cercanos a poblaciones más grandes y qué puertos están cercanos a poblaciones más pequeñas, mostramos el número de pasajeros que embarcó en cada puerto. Además, queremos saber si estas poblaciones eran más ricas o más pobres, por lo que mostramos cuántos pasajeros de cada clase embarcaron en cada puerto mediante una gráfica de barras.
# ![ejemplo7.PNG](attachment:ejemplo7.PNG)

# %% [markdown]
# #### Apartado 8
# No todos los pasajeros pagaron el mismo importe por sus billetes. Mostrar en un gráfico de cajas el precio de los billetes dependiendo de la clase a la que pertenecían.
# ![ejemplo8.PNG](attachment:ejemplo8.PNG)
